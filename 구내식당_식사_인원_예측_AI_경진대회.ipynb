# %% [markdown]
# <a href="https://colab.research.google.com/github/O-Kpy/Dacon/blob/main/%EA%B5%AC%EB%82%B4%EC%8B%9D%EB%8B%B9_%EC%8B%9D%EC%82%AC_%EC%9D%B8%EC%9B%90_%EC%98%88%EC%B8%A1_AI_%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import skew
from tqdm import tqdm

# %%
train = pd.read_csv('/content/drive/MyDrive/dataset/Dacon/대회/235743_구내식당 식사 인원 예측 AI 경진대회_data/235743_구내식당 식사 인원 예측 AI 경진대회_data_train.csv')
test = pd.read_csv('/content/drive/MyDrive/dataset/Dacon/대회/235743_구내식당 식사 인원 예측 AI 경진대회_data/235743_구내식당 식사 인원 예측 AI 경진대회_data_test.csv')
submit = pd.read_csv('/content/drive/MyDrive/dataset/Dacon/대회/235743_구내식당 식사 인원 예측 AI 경진대회_data/235743_구내식당 식사 인원 예측 AI 경진대회_data_sample_submission.csv')

# %%
train.isnull().sum()
# Out:
# 일자                0
# 요일                0
# 본사정원수             0
# 본사휴가자수            0
# 본사출장자수            0
# 본사시간외근무명령서승인건수    0
# 현본사소속재택근무자수       0
# 조식메뉴              0
# 중식메뉴              0
# 석식메뉴              0
# 중식계               0
# 석식계               0
# dtype: int64

# %%
train
# Out:
#               일자 요일  ...     중식계    석식계
# 0     2016-02-01  월  ...  1039.0  331.0
# 1     2016-02-02  화  ...   867.0  560.0
# 2     2016-02-03  수  ...  1017.0  573.0
# 3     2016-02-04  목  ...   978.0  525.0
# 4     2016-02-05  금  ...   925.0  330.0
# ...          ... ..  ...     ...    ...
# 1200  2021-01-20  수  ...  1093.0  421.0
# 1201  2021-01-21  목  ...   832.0  353.0
# 1202  2021-01-22  금  ...   579.0  217.0
# 1203  2021-01-25  월  ...  1145.0  502.0
# 1204  2021-01-26  화  ...  1015.0  480.0
#
# [1205 rows x 12 columns]
